# %% [markdown]
# # Function Lib

# %%
import pandas as pd
import os 
result_df = pd.DataFrame()
unique_filenames = set()
from utils import dataset_analyze_rasp_ff, open_file_nf1, seconds_to_duration, measurement_dataset_analyze

directory_path = './data/Experiment_Data/Video straming/db'
file_list = [
    os.path.join(directory_path, filename) for filename in [
        '1_5_12MINI_4Gn1_AMAZON_15min_Bonne_100sps.csv',
        '1_5_12MINI_4Gn1_AMAZON_30min_Bonne_100sps.csv',
        '1_5_12MINI_4Gn1_AMAZON_30min_OPTIMAL_100sps.csv',
        '1_5_12MINI_4Gn1_APPLE_15min_Auto_100sps.csv',
        '1_5_12MINI_4Gn1_APPLE_15min_HIGH_100sps.csv',
        '1_5_12MINI_4Gn1_APPLE_30min_HIGH_100sps.csv',
        '1_5_12MINI_4Gn1_DISNEY_15min_Auto_100sps.csv',
        '1_5_12MINI_4Gn1_DISNEY_30min_Eco_100sps.csv',
        '1_5_12MINI_4Gn1_DISNEY_43min_Auto_100sps.csv',
        '1_5_12MINI_4Gn1_NETFLIX_15min_Eco_100sps.csv',
        '1_5_12MINI_4Gn1_NETFLIX_15min_MAX_100sps.csv',
        '1_5_12MINI_4Gn1_NETFLIX_30min_Eco_100sps.csv',
        '1_5_12MINI_4Gn1_NETFLIX_30min_MAX_100sps.csv',
        '1_5_12MINI_4Gn1_YOUTUBE_15min_720p_100sps.csv',
        '1_5_12MINI_5Gn3_AMAZON_30min_Bonne_100sps.csv',
        '1_5_12MINI_5Gn3_APPLE_15min_HIGH_100sps.csv',
        '1_5_12MINI_5Gn3_APPLE_30min_Auto_100sps.csv',
        '1_5_12MINI_5Gn3_DISNEY_15min_Auto_100sps.csv',
        '1_5_12MINI_5Gn3_NETFLIX_30min_Eco_100sps.csv',
        '1_5_12MINI_5Gn3_YOUTUBE_15min_720p_100sps.csv',
        '1_5_12MINI_WIFI-2.4GHz_AMAZON_15min_Bonne_100sps.csv',
        '1_5_12MINI_WIFI-2.4GHz_APPLE_15min_HIGH_100sps.csv',
        '1_5_12MINI_WIFI-2.4GHz_NETFLIX_15min_Eco_100sps.csv',
        '1_5_12MINI_WIFI-2.4GHz_YOUTUBE_15min_720p_100sps.csv',
        '1_5_12MINI_WIFI-5GHz_AMAZON_15min_Bonne_100sps.csv',
        '1_5_12MINI_WIFI-5GHz_APPLE_15min_HIGH_100sps.csv',
        '1_5_12MINI_WIFI-5GHz_NETFLIX_15min_Eco_100sps.csv',
        '1_5_12MINI_WIFI-5GHz_YOUTUBE_15min_720p_100sps.csv',
        '1_5_X_3G_AMAZON_15min_Bonne_100sps.csv',
        '1_5_X_3G_APPLE_15min_Auto_100sps.csv',
        '1_5_X_3G_DISNEY_15min_Auto_100sps.csv',
        '1_5_X_3G_NETFLIX_15min_Eco_100sps.csv',
        '1_5_X_3G_YOUTUBE_15min_720p_100sps.csv',
        '1_5_X_4Gn1_AMAZON_15min_Bonne_100sps.csv',
        '4_5_12MINI_5Gn3_APPLE_30min_Auto_100sps5Gn78.csv',
        '7_5_12MINI_5Gn3_NETFLIX_15min_Eco_100sps5Gn78.csv',
        '4_5_12MINI_5Gn3_YOUTUBE_30min_720p_100sps5Gn78.csv',
        '8_5_12MINI_5Gn3_NETFLIX_30min_Eco_100sps5Gn78.csv',
        '9_5_12MINI_5Gn3_NETFLIX_15min_Eco_100sps.csv',
        '1_5_12MINI_WIFI-2.4GHz_DISNEY_15min_Eco_100sps.csv',
        '2_5_12MINI_WIFI-2.4GHz_DISNEY_15min_Eco_100sps.csv',
        '1_5_12MINI_WIFI-5GHz_DISNEY_15min_Eco_100sps.csv',
        '2_5_12MINI_WIFI-5GHz_DISNEY_15min_Eco_100sps.csv',
        '2_5_12MINI_WIFI-5GHz_NETFLIX_15min_Eco_100sps.csv',
        '3_5_12MINI_WIFI-5GHz_NETFLIX_15min_Eco_100sps.csv',
        '2_5_12MINI_WIFI-5GHz_AMAZON_15min_Bonne_100sps.csv',
        '2_5_12MINI_WIFI-5GHz_APPLE_15min_Auto_100sps.csv',
        '3_5_12MINI_WIFI-5GHz_YOUTUBE_15min_720p_100sps.csv',
        '2_5_12MINI_WIFI-5GHz_YOUTUBE_15min_720p_100sps.csv',
        '2_5_12MINI_WIFI-2.4GHz_YOUTUBE_15min_720p_100sps.csv',
        '2_5_12MINI_WIFI-2.4GHz_APPLE_15min_Auto_100sps.csv',
        '3_5_X_4Gn1_DISNEY_15min_Eco_100sps.csv',
        '2_5_X_4Gn1_DISNEY_15min_Eco_100sps.csv',
        '3_5_X_4Gn1_NETFLIX_15min_Eco_100sps.csv',
        '2_5_X_4Gn1_NETFLIX_15min_Eco_100sps.csv',
        '3_5_X_3G_NETFLIX_15min_Eco_100sps.csv',
        '2_5_X_3G_NETFLIX_15min_Eco_100sps.csv',
        '3_5_X_3G_DISNEY_15min_Eco_100sps.csv',
        '2_5_X_3G_DISNEY_15min_Eco_100sps.csv',
        '3_5_X_3G_AMAZON_15min_Bonne_100sps.csv',
        '2_5_X_3G_AMAZON_15min_Bonne_100sps.csv',
        '3_5_X_3G_APPLE_15min_Auto_100sps.csv',
        '2_5_X_3G_APPLE_15min_Auto_100sps.csv',
        '3_5_X_3G_YOUTUBE_15min_720p_100sps.csv',
        '2_5_X_3G_YOUTUBE_15min_720p_100sps.csv',
        '3_5_X_4Gn1_YOUTUBE_15min_720p_100sps.csv',
        '2_5_X_4Gn1_YOUTUBE_15min_720p_100sps.csv',
        '4_5_X_4Gn1_APPLE_15min_Auto_100sps.csv',
        '3_5_X_4Gn1_APPLE_15min_Auto_100sps.csv',
        '2_5_X_4Gn1_APPLE_15min_Auto_100sps.csv',
        '3_5_X_4Gn1_AMAZON_15min_Bonne_100sps.csv',
        '2_5_12MINI_5Gn3_DISNEY_30min_Eco_100sps.csv',
        '2_5_X_4Gn1_AMAZON_15min_Bonne_100sps.csv',
        '1_5_X_4Gn1_AMAZON_30min_Bonne_100sps.csv',
        '2_5_12MINI_WIFI-2.4GHz_NETFLIX_15min_Eco_100sps.csv',
        '2_5_12MINI_4Gn1_YOUTUBE_30min_720p_100sps.csv',
        '4_5_12MINI_WIFI-2.4GHz_NETFLIX_30min_Eco_100sps.csv',
        '2_5_12MINI_4Gn1_DISNEY_30min_Auto_100sps.csv',
        '3_5_12MINI_4Gn1_DISNEY_30min_Auto_100sps.csv',
        '3_5_12MINI_4Gn1_APPLE_30min_HIGH_100sps.csv',
        '3_5_12MINI_4Gn1_YOUTUBE_30min_360p_100sps.csv',
        '1_5_12MINI_4Gn1_YOUTUBE_30min_480p_100sps.csv',
        '4_5_12MINI_4Gn1_YOUTUBE_30min_480p_100sps.csv',
        '4_5_12MINI_4Gn1_YOUTUBE_30min_360p_100sps.csv',
        '3_5_12MINI_4Gn1_YOUTUBE_30min_480p_100sps.csv',

        '1_5_X_WIFI-2.4GHz_AMAZON_15min_Bonne_100sps.csv',
        '1_5_X_WIFI-2.4GHz_NETFLIX_15min_Eco_100sps.csv',
        '1_5_X_WIFI-2.4GHz_DISNEY_15min_Eco_100sps.csv',
        '1_5_X_WIFI-2.4GHz_APPLE_15min_Eco_100sps.csv',
        '1_5_X_WIFI-5GHz_DISNEY_15min_Auto_100sps.csv',
        '1_5_X_WIFI-5GHz_AMAZON_15min_Auto_100sps.csv',
        '1_5_X_WIFI-5GHz_APPLE_15min_Auto_100sps.csv',

    

        # 12MINI 4G SRS
        '3_5_12MINI_4GSRS_APPLE_15min_Auto_100spsn7.csv',
        '2_5_12MINI_4GSRS_AMAZON_15min_Bonne_100spsn7.csv',
        '2_5_12MINI_4GSRS_DISNEY_15min_Eco_100spsn7.csv',
        '2_5_12MINI_4GSRS_NETFLIX_15min_Eco_100spsn7.csv',
        '1_5_12MINI_4GSRS_YOUTUBE_15min_720p_100spsn7.csv',
        '1_5_12MINI_4GSRS_NETFLIX_15min_Eco_100spsn7.csv',
        '1_5_12MINI_4GSRS_DISNEY_15min_Eco_100spsn7.csv',
        '1_5_12MINI_4GSRS_APPLE_15min_Auto_100spsn7.csv',
        '1_5_12MINI_4GSRS_AMAZON_15min_Bonne_100spsn7.csv',
        # X 4G SRS
        '1_5_X_4GSRS_AMAZON_15min_Bonne_100sps.csv',
        '2_5_X_4GSRS_AMAZON_15min_Bonne_100sps.csv',
        '1_5_X_4GSRS_APPLE_15min_Auto_100sps.csv',
        '1_5_X_4GSRS_DISNEY_15min_Eco_100sps.csv',
        '1_5_X_4GSRS_NETFLIX_15min_Eco_100sps.csv',
        '1_5_X_4GSRS_YOUTUBE_15min_720p_100sps.csv'

        ]
    ]

d = 100
files_passed = 0
duplicates_count = 0
problematic_files = []
result_df = pd.DataFrame()

for file_name in file_list:
    try:
        files_passed += 1
        result_df = measurement_dataset_analyze(file_name, d, result_df=result_df)
    except Exception as e:
        print(f"Error processing file: {file_name}")
        problematic_files.append(file_name)

platform_counts = result_df['Platform'].value_counts()
specific_values_count = result_df[result_df['Quality'].isin(['Bonne', 'Eco', 'Auto', '720p', '480p', '360p'])]['Quality'].value_counts()
total_count = specific_values_count.sum()
print(platform_counts)
platform_counts = result_df['Technology'].value_counts()
print(platform_counts)
total_seconds = result_df['Total Sec'].sum()
total_duration = seconds_to_duration(total_seconds)
print(f'Total Duration: {total_duration}')
print(f'Total in sec: {total_seconds}')
print(platform_counts)
for file_name in file_list:
    if file_name in unique_filenames:
        duplicates_count += 1
    else:
        unique_filenames.add(file_name)
# Print the total number of duplicated filenames
print("Total number of duplicated filenames:", duplicates_count)
print("Total number files: {}".format(files_passed))
print("Total valide for default quality:", total_count)
print("Quality:", specific_values_count)
# Out:
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_AMAZON_30min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_AMAZON_30min_OPTIMAL_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_APPLE_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_APPLE_15min_HIGH_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_APPLE_30min_HIGH_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_DISNEY_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_DISNEY_30min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_DISNEY_43min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_NETFLIX_15min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_NETFLIX_15min_MAX_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_NETFLIX_30min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_NETFLIX_30min_MAX_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_4Gn1_YOUTUBE_15min_720p_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_5Gn3_AMAZON_30min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_5Gn3_APPLE_15min_HIGH_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_5Gn3_APPLE_30min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_5Gn3_DISNEY_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_5Gn3_NETFLIX_30min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_5Gn3_YOUTUBE_15min_720p_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_WIFI-2.4GHz_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_WIFI-2.4GHz_APPLE_15min_HIGH_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_WIFI-2.4GHz_NETFLIX_15min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_WIFI-2.4GHz_YOUTUBE_15min_720p_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_WIFI-5GHz_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_WIFI-5GHz_APPLE_15min_HIGH_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_WIFI-5GHz_NETFLIX_15min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_12MINI_WIFI-5GHz_YOUTUBE_15min_720p_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_3G_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_3G_APPLE_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_3G_DISNEY_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_3G_NETFLIX_15min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_3G_YOUTUBE_15min_720p_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_4Gn1_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_4Gn1_APPLE_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_4Gn1_DISNEY_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_4Gn1_NETFLIX_15min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_4Gn1_YOUTUBE_15min_720p_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/2_5_12MINI_4Gn1_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/2_5_12MINI_4Gn1_AMAZON_30min_TRES-Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/2_5_12MINI_5Gn3_APPLE_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/2_5_12MINI_5Gn3_APPLE_15min_HIGH_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/2_5_12MINI_5Gn3_DISNEY_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/2_5_12MINI_4Gn1_DISNEY_15min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/2_5_12MINI_4Gn1_APPLE_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI_4Gn1_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI_4Gn1_APPLE_30min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI_4Gn1_DISNEY_15min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI_4Gn1_AMAZON_30min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI_4Gn1_DISNEY_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI_5Gn3_APPLE_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI_5Gn3_APPLE_30min_HIGH_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI_5Gn3_DISNEY_30min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI_WIFI-2.4GHz_AMAZON_30min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/4_5_12MINI_4Gn1_AMAZON_15min_OPTIMAL_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/4_5_12MINI_4Gn1_AMAZON_15min_TRES-Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/4_5_12MINI_4Gn1_DISNEY_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/4_5_12MINI_4Gn1_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/5_5_12MINI_4Gn1_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/6_5_12MINI_4Gn1_AMAZON_30min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/7_5_12MINI_4Gn1_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/2_5_12MINI_5Gn3_AMAZON_30min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI_5Gn3_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/4_5_12MINI_5Gn3_AMAZON_20min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/2_5_12MINI_5Gn3_NETFLIX_15min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/3_5_12MINI
csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_4GSRS_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/2_5_X_4GSRS_AMAZON_15min_Bonne_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_4GSRS_APPLE_15min_Auto_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_4GSRS_DISNEY_15min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_4GSRS_NETFLIX_15min_Eco_100sps.csv
# Error processing file: ./data/Experiment_Data/Video straming/db/1_5_X_4GSRS_YOUTUBE_15min_720p_100sps.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 180
#     177         print(f"Error processing file: {file_name}")
#     178         problematic_files.append(file_name)
# --> 180 platform_counts = result_df['Platform'].value_counts()
#     181 specific_values_count = result_df[result_df['Quality'].isin(['Bonne', 'Eco', 'Auto', '720p', '480p', '360p'])]['Quality'].value_counts()
#     182 total_count = specific_values_count.sum()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Platform'

# %%
# --- Normalize and group result_df by scenario_id ---

# Define mappings for Technology and Quality to normalize names
tech_map = {
    '4Gn1': 'LTE',
    '4Gn': 'LTE',
    '4GSRS': 'LTE',
    '5Gn3': '5G',
    '5Gn78': '5G',
    '3G': '3G',
    'WIFI-2.4GHz': 'WiFi',
    'WIFI-5GHz': 'WiFi',
}
quality_map = {
    'Bonne': 'Good',
    'TRES-Bonne': 'VeryGood',
    'OPTIMAL': 'Optimal',
    'Eco': 'Eco',
    'Auto': 'Auto',
    'HIGH': 'High',
    'MAX': 'Max',
    '720p': '720p',
    '480p': '480p',
    '360p': '360p',
}

# Lowercase device/platform and apply mappings
result_df['Device'] = result_df['Device'].str.lower()
result_df['Platform'] = result_df['Platform'].str.lower()
result_df['Technology'] = result_df['Technology'].map(tech_map)
result_df['Quality'] = result_df['Quality'].map(quality_map)

# Default mobility to 'stat'
result_df['Mobility'] = 'stat'

# Build scenario_id: device_tech_platform_quality_mobility
result_df['scenario_id'] = (
    result_df['Device'] + "_" +
    result_df['Technology'] + "_" +
    result_df['Platform'] + "_" +
    result_df['Quality'] + "_" +
    result_df['Mobility']
)

# Convert power columns to numeric in case they're not already
result_df['Avg RF Power W'] = pd.to_numeric(result_df['Avg RF Power W'], errors='coerce')
result_df['Avg BAT Power W'] = pd.to_numeric(result_df['Avg BAT Power W'], errors='coerce')

# Group by scenario_id and compute mean values
video_streaming_scenario_summary_df = result_df.groupby('scenario_id')[['Avg RF Power W', 'Avg BAT Power W']].mean().reset_index()

# Optional: Rename columns for frontend clarity
video_streaming_scenario_summary_df.rename(columns={
    'Avg RF Power W': 'Avg_RF_Power_W',
    'Avg BAT Power W': 'Avg_BAT_Power_W'
}, inplace=True)

# Save to CSV for web app simulator
video_streaming_scenario_summary_df.to_csv("./website/server/video_streaming_scenario_summary_df.csv", index=False)

# Preview result
print(video_streaming_scenario_summary_df.head())
# Out:
#               scenario_id  Avg_RF_Power_W  Avg_BAT_Power_W
# 0    x_3G_apple_Auto_stat        0.162367         0.872367
# 1   x_3G_disney_Auto_stat        0.598200         1.381900
# 2    x_3G_disney_Eco_stat        0.307650         1.122950
# 3   x_3G_netflix_Eco_stat        0.159733         0.874600
# 4  x_3G_youtube_720p_stat        0.273900         1.488133
